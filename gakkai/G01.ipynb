# %%
import numpy as np
import os

# %%
sim_id = 0
sim_dir = os.path.normpath(os.path.join(
    'C:/Users/imeho/Documents/ScalarFlow/input_views_2023_03_31',
    f"sim_{sim_id:06d}",
    "input",
    "cam"
))
# for file_name in sorted(os.listdir(sim_dir)):
#     file_path = os.path.join(sim_dir, file_name)
#     data = np.load(file_path)
#     print(f"Loaded data from {file_name}: {list(data.keys())}")

# %%
import matplotlib.pyplot as plt

file_name = os.listdir(sim_dir)[100]
file_path = os.path.join(sim_dir, file_name)
data = np.load(file_path)['data']

fig, axes = plt.subplots(1, 5, figsize=(20, 10))  # 创建1行5列的子图
for i in range(5):
    axes[i].imshow(np.flipud(data[i]), cmap='gray')
    axes[i].set_title(f"Image {i + 1}")
    axes[i].axis('off')
plt.tight_layout()
plt.show()
